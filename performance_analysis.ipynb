# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
sim_summaries = pd.read_csv('results\\tables\\agents_comparison.csv')
WORLDS = sim_summaries["world"].unique()

# %% [markdown]
# ## Salience Sensitivity Analysis

# %%
metric = "smooth_steps"

fig, axs = plt.subplots(2, 3, figsize=(18, 8))
for world, ax in zip(WORLDS, axs.flatten()):
    
    sns.lineplot(
        x='iteration',
        y=metric,
        hue='agent',
        data=sim_summaries[
            sim_summaries['world'] == world
        ],
        ax=ax
    )
    ax.set_title(f'World\n{" ".join(world.split("_")).title()}')
    ax.set_ylabel(metric)
    ax.set_ylabel("Iteration")

plt.tight_layout()

plt.show()

# %%
sim_summaries
# Out:
#       Unnamed: 0  iteration  steps  reward      error  \
# 0              0          0  101.0     4.0 -29.961820
# 1              1          1  101.0     3.0 -25.370045
# 2              2          2   22.0     5.0 -11.435991
# 3              3          3   18.0     2.0 -11.304477
# 4              4          4   37.0     4.0 -24.152179
# ...          ...        ...    ...     ...        ...
# 1447        1447        116   11.0     1.0  22.589535
# 1448        1448        117   11.0     1.0  21.935623
# 1449        1449        118   13.0    -9.0   4.336265
# 1450        1450        119   11.0     1.0  20.649934
# 1451        1451        120   13.0    -9.0   3.967565
#
#                                                   value  smooth_steps  \
# 0     [ 5.71568470e-03  8.93175690e-03 -6.91718609e-...     36.083333
# 1     [-6.94214242e-02 -6.64470072e-02 -1.36450817e-...     36.083333
# 2     [-6.94214242e-02 -6.64470072e-02 -1.98512685e-...     36.083333
# ...
